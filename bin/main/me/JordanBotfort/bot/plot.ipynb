# %%
import io
import pandas as pd
import sys
from datetime import date
import json

# user = sys.argv[1]
user = "roy_h92"

data = pd.read_csv("./" + user + "/status.txt", sep=" ", header=None, names = ["Date", "Time", "Assets"])
print(data)
fig = data.plot("Date", "Assets", figsize = (10, 7), title = "Total assets over time")
fig.figure.savefig("./" + user + "/fig.png")
# Out:
#            Date   Time  Assets
# 0    2022-11-18  14:33  100.91
# 1    2022-11-18  14:34  100.97
# 2    2022-11-18  14:35  101.01
# 3    2022-11-18  14:36  100.94
# 4    2022-11-18  14:37  100.84
# ..          ...    ...     ...
# 383  2022-11-18  20:56  100.81
# 384  2022-11-18  20:57  100.79
# 385  2022-11-18  20:58  100.80
# 386  2022-11-18  20:59  100.89
# 387  2022-11-18  21:00  101.10
#
# [388 rows x 3 columns]
